# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %%
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
D0220=pd.read_csv("/content/sample_data/BTCUSDC-1d-2021-01.csv", 
                 names=['Open time',
                        'Open',
                        'High',
                        'Low',
                        'Close',
                        'Volume',
                        'Close time',
                        'Quote asset volume',
                        'Number of trades',
                        'Taker buy base asset volume',
                        'Taker buy quote asset volume',
                        'Ignore']
                )
D0320=pd.read_csv("/content/sample_data/BTCUSDC-1d-2021-02.csv", 
                 names=['Open time',
                        'Open',
                        'High',
                        'Low',
                        'Close',
                        'Volume',
                        'Close time',
                        'Quote asset volume',
                        'Number of trades',
                        'Taker buy base asset volume',
                        'Taker buy quote asset volume',
                        'Ignore']
                )
D0420=pd.read_csv("/content/sample_data/BTCUSDC-1d-2021-03.csv", 
                 names=['Open time',
                        'Open',
                        'High',
                        'Low',
                        'Close',
                        'Volume',
                        'Close time',
                        'Quote asset volume',
                        'Number of trades',
                        'Taker buy base asset volume',
                        'Taker buy quote asset volume',
                        'Ignore']
                )
D0520=pd.read_csv("/content/sample_data/BTCUSDC-1d-2021-04.csv", 
                 names=['Open time',
                        'Open',
                        'High',
                        'Low',
                        'Close',
                        'Volume',
                        'Close time',
                        'Quote asset volume',
                        'Number of trades',
                        'Taker buy base asset volume',
                        'Taker buy quote asset volume',
                        'Ignore']
                )
D0620=pd.read_csv("/content/sample_data/BTCUSDC-1d-2021-05.csv", 
                 names=['Open time',
                        'Open',
                        'High',
                        'Low',
                        'Close',
                        'Volume',
                        'Close time',
                        'Quote asset volume',
                        'Number of trades',
                        'Taker buy base asset volume',
                        'Taker buy quote asset volume',
                        'Ignore']
                )

# %%
D0720=pd.read_csv("/content/sample_data/BTCUSDC-1d-2021-06.csv", 
                 names=['Open time',
                        'Open',
                        'High',
                        'Low',
                        'Close',
                        'Volume',
                        'Close time',
                        'Quote asset volume',
                        'Number of trades',
                        'Taker buy base asset volume',
                        'Taker buy quote asset volume',
                        'Ignore']
                )
D0820=pd.read_csv("/content/sample_data/BTCUSDC-1d-2021-07.csv", 
                 names=['Open time',
                        'Open',
                        'High',
                        'Low',
                        'Close',
                        'Volume',
                        'Close time',
                        'Quote asset volume',
                        'Number of trades',
                        'Taker buy base asset volume',
                        'Taker buy quote asset volume',
                        'Ignore']
                )
D0920=pd.read_csv("/content/sample_data/BTCUSDC-1d-2021-08.csv", 
                 names=['Open time',
                        'Open',
                        'High',
                        'Low',
                        'Close',
                        'Volume',
                        'Close time',
                        'Quote asset volume',
                        'Number of trades',
                        'Taker buy base asset volume',
                        'Taker buy quote asset volume',
                        'Ignore']
                )
D1020=pd.read_csv("/content/sample_data/BTCUSDC-1d-2021-09.csv", 
                 names=['Open time',
                        'Open',
                        'High',
                        'Low',
                        'Close',
                        'Volume',
                        'Close time',
                        'Quote asset volume',
                        'Number of trades',
                        'Taker buy base asset volume',
                        'Taker buy quote asset volume',
                        'Ignore']
                )
D1120=pd.read_csv("/content/sample_data/BTCUSDC-1d-2021-10.csv", 
                 names=['Open time',
                        'Open',
                        'High',
                        'Low',
                        'Close',
                        'Volume',
                        'Close time',
                        'Quote asset volume',
                        'Number of trades',
                        'Taker buy base asset volume',
                        'Taker buy quote asset volume',
                        'Ignore']
                )
D1220=pd.read_csv("/content/sample_data/BTCUSDC-1d-2021-11.csv", 
                 names=['Open time',
                        'Open',
                        'High',
                        'Low',
                        'Close',
                        'Volume',
                        'Close time',
                        'Quote asset volume',
                        'Number of trades',
                        'Taker buy base asset volume',
                        'Taker buy quote asset volume',
                        'Ignore']
                )

# %%
D0121=pd.read_csv("/content/sample_data/BTCUSDC-1d-2021-12.csv", 
                 names=['Open time',
                        'Open',
                        'High',
                        'Low',
                        'Close',
                        'Volume',
                        'Close time',
                        'Quote asset volume',
                        'Number of trades',
                        'Taker buy base asset volume',
                        'Taker buy quote asset volume',
                        'Ignore']
                )

# %%
D0220['Open time'] = pd.to_datetime(D0220['Open time'],unit='ms')
D0320['Open time'] = pd.to_datetime(D0320['Open time'],unit='ms')
D0420['Open time'] = pd.to_datetime(D0420['Open time'],unit='ms')
D0520['Open time'] = pd.to_datetime(D0520['Open time'],unit='ms')
D0620['Open time'] = pd.to_datetime(D0620['Open time'],unit='ms')
D0720['Open time'] = pd.to_datetime(D0720['Open time'],unit='ms')
D0820['Open time'] = pd.to_datetime(D0820['Open time'],unit='ms')
D0920['Open time'] = pd.to_datetime(D0920['Open time'],unit='ms')
D1020['Open time'] = pd.to_datetime(D1020['Open time'],unit='ms')
D1120['Open time'] = pd.to_datetime(D1120['Open time'],unit='ms')
D1220['Open time'] = pd.to_datetime(D1220['Open time'],unit='ms')

# %%
D0121['Open time'] = pd.to_datetime(D0121['Open time'],unit='ms')

# %%
Data=pd.concat([D0220,D0320,D0420,D0520,D0620,D0720,D0820,D0920,D1020,D1120,D1220,D0121])
Data=Data[{'Open time','Close'}]
Data.set_index('Open time',inplace=True)
Data
# Out:
#                Close
# Open time
# 2021-01-01  29407.93
# 2021-01-02  32215.18
# 2021-01-03  33033.26
# 2021-01-04  32017.58
# 2021-01-05  34059.70
# ...              ...
# 2021-12-27  50695.95
# 2021-12-28  47551.60
# 2021-12-29  46468.33
# 2021-12-30  47135.69
# 2021-12-31  46231.04
#
# [365 rows x 1 columns]

# %%
train=Data.loc[:datetime(2021,10,31)]
#val=Data.loc[datetime(2021,6,1) : datetime(2021,7,31)]
test=Data.loc[datetime(2021,11,1):]
# Out:
# (61, 1)

# %%
print(train.shape)
print(test.shape)
# Out:
# (304, 1)
# (61, 1)

# %%
# Feature Scaling
fs = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = fs.fit_transform(train)

# %%
# Creating a data structure with 30 time-steps (30 time period window) and 1 output
X_train = []
y_train = []
for i in range(30,304):
    X_train.append(training_set_scaled[i-30:i])
    y_train.append(training_set_scaled[i,0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
model = Sequential()

#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 100, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.25))

# Adding a second LSTM layer and some Dropout regularisation
#model.add(LSTM(units = 100, return_sequences = True))
#model.add(Dropout(0.25))

# Adding a third LSTM layer and some Dropout regularisation
#model.add(LSTM(units = 100, return_sequences = True))
#model.add(Dropout(0.25))

# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 100))
model.add(Dropout(0.25))

# Adding the output layer
model.add(Dense(units = 1))

# Compiling the LSTM
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the LSTM to the Training set
history=model.fit(X_train, y_train, epochs = 200)
# Out:
# Epoch 1/200
# 9/9 [==============================] - 4s 56ms/step - loss: 0.1100
# Epoch 2/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0237
# Epoch 3/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0184
# Epoch 4/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0170
# Epoch 5/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0160
# Epoch 6/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0137
# Epoch 7/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0124
# Epoch 8/200
# 9/9 [==============================] - 1s 56ms/step - loss: 0.0128
# Epoch 9/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0121
# Epoch 10/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0108
# Epoch 11/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0103
# Epoch 12/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0101
# Epoch 13/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0108
# Epoch 14/200
# 9/9 [==============================] - 0s 52ms/step - loss: 0.0096
# Epoch 15/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0094
# Epoch 16/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0108
# Epoch 17/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0091
# Epoch 18/200
# 9/9 [==============================] - 1s 56ms/step - loss: 0.0107
# Epoch 19/200
# 9/9 [==============================] - 0s 52ms/step - loss: 0.0102
# Epoch 20/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0097
# Epoch 21/200
# 9/9 [==============================] - 0s 52ms/step - loss: 0.0091
# Epoch 22/200
# 9/9 [==============================] - 1s 56ms/step - loss: 0.0088
# Epoch 23/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0083
# Epoch 24/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0092
# Epoch 25/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0085
# Epoch 26/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0089
# Epoch 27/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0082
# Epoch 28/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0084
# Epoch 29/200
# 9/9 [==============================] - 0s 52ms/step - loss: 0.0075
# Epoch 30/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0078
# Epoch 31/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0076
# Epoch 32/200
# 9/9 [==============================] - 1s 55ms/step - loss: 0.0089
# Epoch 33/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0074
# Epoch 34/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0073
# Epoch 35/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0080
# Epoch 36/200
# 9/9 [==============================] - 0s 56ms/step - loss: 0.0071
# Epoch 37/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0071
# Epoch 38/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0081
# Epoch 39/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0075
# Epoch 40/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0072
# Epoch 41/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0070
# Epoch 42/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0069
# Epoch 43/200
# 9/9 [==============================] - 1s 56ms/step - loss: 0.0071
# Epoch 44/200
# 9/9 [==============================] - 1s 55ms/step - loss: 0.0066
# Epoch 45/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0064
# Epoch 46/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0071
# Epoch 47/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0076
# Epoch 48/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0064
# Epoch 49/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0063
# Epoch 50/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0059
# Epoch 51/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0068
# Epoch 52/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0055
# Epoch 53/200
# 9/9 [==============================] - 0s 56ms/step - loss: 0.0061
# Epoch 54/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0057
# Epoch 55/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0056
# Epoch 56/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0064
# Epoch 57/200
# 9/9 [==============================] - 1s 58ms/step - loss: 0.0060
# Epoch 58/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0055
# Epoch 59/200
# 9/9 [==============================] - 1s 55ms/step - loss: 0.0060
# Epoch 60/200
# 9/9 [==============================] - 1s 56ms/step - loss: 0.0057
# Epoch 61/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0061
# Epoch 62/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0057
# Epoch 63/200
# 9/9 [==============================] - 1s 56ms/step - loss: 0.0059
# Epoch 64/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0061
# Epoch 65/200
# 9/9 [==============================] - 0s 52ms/step - loss: 0.0050
# Epoch 66/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0054
# Epoch 67/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0059
# Epoch 68/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0048
# Epoch 69/200
# 9/9 [==============================] - 1s 56ms/step - loss: 0.0061
# Epoch 70/200
# 9/9 [==============================] - 0s 56ms/step - loss: 0.0064
# Epoch 71/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0057
# Epoch 72/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0065
# Epoch 73/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0060
# Epoch 74/200
# 9/9 [==============================] - 0s 56ms/step - loss: 0.0058
# Epoch 75/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0053
# Epoch 76/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0055
# Epoch 77/200
# 9/9 [==============================] - 0s 52ms/step - loss: 0.0054
# Epoch 78/200
# 9/9 [==============================] - 1s 57ms/step - loss: 0.0043
# Epoch 79/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0051
# Epoch 80/200
# 9/9 [==============================] - 1s 55ms/step - loss: 0.0056
# Epoch 81/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0052
# Epoch 82/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0057
# Epoch 83/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0051
# Epoch 84/200
# 9/9 [==============================] - 0s 56ms/step - loss: 0.0054
# Epoch 85/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0057
# Epoch 86/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0050
# Epoch 87/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0054
# Epoch 88/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0052
# Epoch 89/200
# 9/9 [==============================] - 0s 52ms/step - loss: 0.0052
# Epoch 90/200
# 9/9 [==============================] - 1s 58ms/step - loss: 0.0065
# Epoch 91/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0057
# Epoch 92/200
# 9/9 [==============================] - 1s 57ms/step - loss: 0.0056
# Epoch 93/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0052
# Epoch 94/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0053
# Epoch 95/200
# 9/9 [==============================] - 0s 52ms/step - loss: 0.0052
# Epoch 96/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0049
# Epoch 97/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0053
# Epoch 98/200
# 9/9 [==============================] - 1s 59ms/step - loss: 0.0047
# Epoch 99/200
# 9/9 [==============================] - 1s 56ms/step - loss: 0.0048
# Epoch 100/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0051
# Epoch 101/200
# 9/9 [==============================] - 1s 57ms/step - loss: 0.0054
# Epoch 102/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0054
# Epoch 103/200
# 9/9 [==============================] - 1s 55ms/step - loss: 0.0053
# Epoch 104/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0049
# Epoch 105/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0055
# Epoch 106/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0052
# Epoch 107/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0050
# Epoch 108/200
# 9/9 [==============================] - 0s 51ms/step - loss: 0.0047
# Epoch 109/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0042
# Epoch 110/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0044
# Epoch 111/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0044
# Epoch 112/200
# 9/9 [==============================] - 1s 58ms/step - loss: 0.0049
# Epoch 113/200
# 9/9 [==============================] - 1s 59ms/step - loss: 0.0049
# Epoch 114/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0047
# Epoch 115/200
# 9/9 [==============================] - 1s 57ms/step - loss: 0.0050
# Epoch 116/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0045
# Epoch 117/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0045
# Epoch 118/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0057
# Epoch 119/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0043
# Epoch 120/200
# 9/9 [==============================] - 0s 56ms/step - loss: 0.0045
# Epoch 121/200
# 9/9 [==============================] - 1s 59ms/step - loss: 0.0044
# Epoch 122/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0043
# Epoch 123/200
# 9/9 [==============================] - 1s 58ms/step - loss: 0.0046
# Epoch 124/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0049
# Epoch 125/200
# 9/9 [==============================] - 1s 56ms/step - loss: 0.0054
# Epoch 126/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0046
# Epoch 127/200
# 9/9 [==============================] - 1s 58ms/step - loss: 0.0047
# Epoch 128/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0049
# Epoch 129/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0044
# Epoch 130/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0046
# Epoch 131/200
# 9/9 [==============================] - 1s 56ms/step - loss: 0.0044
# Epoch 132/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0038
# Epoch 133/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0061
# Epoch 134/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0050
# Epoch 135/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0052
# Epoch 136/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0047
# Epoch 137/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0047
# Epoch 138/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0043
# Epoch 139/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0048
# Epoch 140/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0047
# Epoch 141/200
# 9/9 [==============================] - 1s 57ms/step - loss: 0.0044
# Epoch 142/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0042
# Epoch 143/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0051
# Epoch 144/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0039
# Epoch 145/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0056
# Epoch 146/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0038
# Epoch 147/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0043
# Epoch 148/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0043
# Epoch 149/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0048
# Epoch 150/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0053
# Epoch 151/200
# 9/9 [==============================] - 1s 56ms/step - loss: 0.0041
# Epoch 152/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0042
# Epoch 153/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0045
# Epoch 154/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0050
# Epoch 155/200
# 9/9 [==============================] - 0s 56ms/step - loss: 0.0045
# Epoch 156/200
# 9/9 [==============================] - 1s 56ms/step - loss: 0.0047
# Epoch 157/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0046
# Epoch 158/200
# 9/9 [==============================] - 1s 57ms/step - loss: 0.0049
# Epoch 159/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0044
# Epoch 160/200
# 9/9 [==============================] - 1s 59ms/step - loss: 0.0040
# Epoch 161/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0042
# Epoch 162/200
# 9/9 [==============================] - 1s 56ms/step - loss: 0.0044
# Epoch 163/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0045
# Epoch 164/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0043
# Epoch 165/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0042
# Epoch 166/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0047
# Epoch 167/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0046
# Epoch 168/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0046
# Epoch 169/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0044
# Epoch 170/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0042
# Epoch 171/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0048
# Epoch 172/200
# 9/9 [==============================] - 0s 56ms/step - loss: 0.0044
# Epoch 173/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0042
# Epoch 174/200
# 9/9 [==============================] - 1s 55ms/step - loss: 0.0039
# Epoch 175/200
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0042
# Epoch 176/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0043
# Epoch 177/200
# 9/9 [==============================] - 1s 57ms/step - loss: 0.0041
# Epoch 178/200
# 9/9 [==============================] - 1s 58ms/step - loss: 0.0039
# Epoch 179/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0049
# Epoch 180/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0043
# Epoch 181/200
# 9/9 [==============================] - 1s 55ms/step - loss: 0.0044
# Epoch 182/200
# 9/9 [==============================] - 0s 56ms/step - loss: 0.0046
# Epoch 183/200
# 9/9 [==============================] - 1s 54ms/step - loss: 0.0046
# Epoch 184/200
# 9/9 [==============================] - 1s 56ms/step - loss: 0.0043
# Epoch 185/200
# 9/9 [==============================] - 1s 56ms/step - loss: 0.0041
# Epoch 186/200
# 9/9 [==============================] - 1s 57ms/step - loss: 0.0041
# Epoch 187/200
# 9/9 [==============================] - 1s 59ms/step - loss: 0.0042
# Epoch 188/200
# 9/9 [==============================] - 1s 57ms/step - loss: 0.0045
# Epoch 189/200
# 9/9 [==============================] - 1s 57ms/step - loss: 0.0045
# Epoch 190/200
# 9/9 [==============================] - 1s 56ms/step - loss: 0.0040
# Epoch 191/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0045
# Epoch 192/200
# 9/9 [==============================] - 1s 57ms/step - loss: 0.0043
# Epoch 193/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0052
# Epoch 194/200
# 9/9 [==============================] - 1s 57ms/step - loss: 0.0041
# Epoch 195/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0043
# Epoch 196/200
# 9/9 [==============================] - 1s 56ms/step - loss: 0.0038
# Epoch 197/200
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0042
# Epoch 198/200
# 9/9 [==============================] - 1s 56ms/step - loss: 0.0041
# Epoch 199/200
# 9/9 [==============================] - 0s 54ms/step - loss: 0.0042
# Epoch 200/200
# 9/9 [==============================] - 1s 58ms/step - loss: 0.0042

# %%
plt.figure(figsize=(14,8))
plt.plot(history.history['loss'])
plt.show()

# %%
inputs = Data[len(Data.values)-len(test.values)-30:].values
print(inputs.shape)
inputs = inputs.reshape(-1,1)
inputs = fs.transform(inputs)
X_test = []
for i in range(30, len(inputs)):
    X_test.append(inputs[i-30:i])
X_test = np.array(X_test)
print(X_test.shape)
# Out:
# (91, 1)
# (61, 30, 1)
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   "X does not have valid feature names, but"

# %%
preds=model.predict(X_test)
preds=fs.inverse_transform(preds)
# Out:
# WARNING:tensorflow:5 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f434e8c07a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
preds
# Out:
# array([[59915.207],
#        [59417.406],
#        [61302.477],
#        [61458.105],
#        [60062.57 ],
#        [59377.793],
#        [59828.55 ],
#        [61516.152],
#        [65427.027],
#        [65212.543],
#        [62973.81 ],
#        [62565.664],
#        [62184.473],
#        [62436.51 ],
#        [63498.55 ],
#        [62026.11 ],
#        [58778.508],
#        [58506.55 ],
#        [56119.01 ],
#        [56510.363],
#        [58219.953],
#        [57780.08 ],
#        [55601.023],
#        [56030.562],
#        [56132.887],
#        [57538.64 ],
#        [53880.598],
#        [53383.297],
#        [55638.1  ],
#        [56864.918],
#        [56230.906],
#        [56102.434],
#        [55588.51 ],
#        [53251.46 ],
#        [49359.855],
#        [48380.81 ],
#        [49312.832],
#        [50027.457],
#        [50125.766],
#        [47996.215],
#        [46764.49 ],
#        [48066.895],
#        [49410.258],
#        [47468.27 ],
#        [47514.13 ],
#        [48178.89 ],
#        [47647.656],
#        [46309.984],
#        [46207.89 ],
#        [46303.92 ],
#        [46542.062],
#        [48014.816],
#        [48470.44 ],
#        [50008.863],
#        [50562.79 ],
#        [50242.297],
#        [50275.652],
#        [50244.72 ],
#        [48021.66 ],
#        [46327.625],
#        [46331.07 ]], dtype=float32)

# %%
test
# Out:
#                Close
# Open time
# 2021-11-01  60935.63
# 2021-11-02  63253.09
# 2021-11-03  62916.65
# 2021-11-04  61450.02
# 2021-11-05  60988.27
# ...              ...
# 2021-12-27  50695.95
# 2021-12-28  47551.60
# 2021-12-29  46468.33
# 2021-12-30  47135.69
# 2021-12-31  46231.04
#
# [61 rows x 1 columns]

# %%
plt.figure(figsize=(14,8))
plt.plot(test.values,color='blue')
plt.plot(preds,color='red')
plt.show()
